# %%
import h5py

# %%
hdf5 = h5py.File("samples/test.hdf5", 'r')
hdf5.keys()
# Out:
# <KeysViewHDF5 ['Decay', 'metadata']>

# %%
data = hdf5["Decay"]
for key in data.keys():
    print(key)
# Out:
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Ad_3
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Ad_3_isvalid
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Ae_12
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Ae_12_isvalid
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Ae_3
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Ae_3_isvalid
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Au_3
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Au_3_isvalid
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::M1
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::M1_isvalid
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::M2
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::M2_isvalid
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::M3
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::M3_isvalid
# #MSSM20atQ_parameters @MSSM20atQ::primary_parameters::Qin
# ...
